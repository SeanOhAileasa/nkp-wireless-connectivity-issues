# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-wireless-connectivity-issues/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Wireless Connectivity Issues``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Wireless Connectivity Issues](#wirelessConnectivityIssuestop)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topwirelessConnectivityIssuesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="wirelessConnectivityIssuestop"></a>
# ### [Wireless Connectivity Issues](#wirelessConnectivityIssues)
#
# - [1. Reflection, Refraction, and Latency](#wirelessConnectivityIssues1ReflectionRefractionandLatency) <br/><br/>
# - [2. Latency, Jitter, and Attenuation](#wirelessConnectivityIssues2LatencyJitterandAttenuation) <br/><br/>
# - [3. Incorrect Antenna Types and Placement](#wirelessConnectivityIssues3IncorrectAntennaTypesandPlacement) <br/><br/>
# - [4. Interference, Overcapacity, and Channel Overlap](#wirelessConnectivityIssues4InterferenceOvercapacityandChannelOverlap) <br/><br/>
# - [5. Distance Limitations and Frequency Mismatches](#wirelessConnectivityIssues5DistanceLimitationsandFrequencyMismatches) <br/><br/>
# - [6. Wrong SSID and Passphrases](#wirelessConnectivityIssues6WrongSSIDandPassphrases) <br/><br/>
# - [7. Security Type Mismatches](#wirelessConnectivityIssues7SecurityTypeMismatches) <br/><br/>
# - [8. Power Levels and Signal-to-noise Ratio](#wirelessConnectivityIssues8PowerLevelsandSignaltonoiseRatio)

# %% [markdown]
# ### [Practice: Wireless Connectivity Issues](#wirelessConnectivityIssuespractice)
#
# * [1. Exercise: Troubleshoot Wireless Connectivity](#wirelessConnectivityIssuesexercise)

# %% [markdown]
# <a id="topwirelessConnectivityIssuesTest"></a>
# ### ⚡ [Test](#wirelessConnectivityIssuesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssues"></a>
# ***
# ### Wireless Connectivity Issues
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssues1ReflectionRefractionandLatency"></a>
# ***
# ###### 1. Reflection, Refraction, and Latency
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``given a scenario toubleshoot reflection, refraction and latency``

# %% [markdown]
# Now in this section we'll take a look at some of the issues that can arise with connectivity in wireless networks.

# %% [markdown]
# And consider that, of course, wireless signals are sent using radio frequencies. And radio, in and of itself, is just another portion of the spectrum of light.

# %% [markdown]
# So the problems that can arise are the same issues that we can see with visible light, just to a different degree.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Reflection
# ***

# %% [markdown]
# So beginning with reflection, wireless signals can, of course, bounce off certain surface types. And depending on the surface the degree of bounce will vary.

# %% [markdown]
# For example, of course, if we shine a flash light on a mirror, almost all of the light reflects off. Whereas if you shine it on a wall, not nearly as much will reflect.

# %% [markdown]
# So signals can be weakened, and this can cause interference depending on how much reflection there is.

# %% [markdown]
# So in a practical scenario, you probably would not want a lot of glass, for example, around your wireless access points.

# %% [markdown]
# The less, the better, because you want that signal to be as unimpeded as possible from the transmission point to the reception point. If there's absolutely nothing in between, that is your best case scenario.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Refraction
# ***

# %% [markdown]
# Now refraction is the bending of a signal wave as it changes speeds on a new medium.

# %% [markdown]
# Now, of course, as it's traveling through the air and if it is unimpeded, then it's not going to change the medium.

# %% [markdown]
# But, of course, in many cases, the signal has to travel through walls, and they can be made of different materials such as glass as just mentioned, concrete, wood and dry wall, metal.

# %% [markdown]
# So as those physical types of media change, so can the refractive index, and this can cause lower data rates and reduced capacity.

# %% [markdown]
# So, again, ideally what you want is nothing in the way, but that's just not always an option.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Diffraction
# ***

# %% [markdown]
# And diffraction occurs when waves have to travel, if you will, around obstacles.

# %% [markdown]
# Now, in many cases depending on what the obstacle is, it might travel through it.

# %% [markdown]
# But something like a large hill, for example, is going to effectively split the wave. And it will kind of travel out on either side of the hill, so that if you were directly behind the hill, you wouldn't get very much of the signal at all.

# %% [markdown]
# So the diffraction, of course, can change the wave direction and or the intensity.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Scattering
# ***

# %% [markdown]
# Now scattering is similar to refraction, but it's a little more unpredictable.

# %% [markdown]
# And it's due to things such as dust or high humidity, or, again, inconsistencies of any given material through which it is traveling.

# %% [markdown]
# And this can alter the overall signal integrity and the strength.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Absorption
# ***

# %% [markdown]
# And finally absorption, this is a common reaction when wireless signals meet different materials, again such as wood or concrete.

# %% [markdown]
# Now, this isn't referring to how it scatters or diffuses, but rather how that material absorbs that energy.

# %% [markdown]
# It is after all just a form of energy, so what happens is it gets transferred into heat.

# %% [markdown]
# And different materials will transfer that energy differently, so it affects the overall signal strength.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Signal Strength and Quality
# ***

# %% [markdown]
# So ultimately, your best bet, as mentioned, is to have nothing in your way, but that's just not always an option. So whatever you can do to reduce the amount of obstacles and or try to keep it to materials that are fairly consistent, then the better the overall signal strength and quality will be.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssues2LatencyJitterandAttenuation"></a>
# ***
# ###### 2. Latency Jitter and Attenuation
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``given a scenario troubleshoot latency, jitter and attenuation``

# %% [markdown]
# In this presentation, we'll take a look at several problems that can still exist in a wireless network.

# %% [markdown]
# And many of these are the same, as we discussed earlier, in a wired but simply the different type of medium does not eliminate these problems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Latency
# ***

# %% [markdown]
# So there are still issues such as latency whereby you experience delays in processing the network data.

# %% [markdown]
# Ideally, you want a low latency network where there are only small delay times, but in a lot of cases you might still have high latency wherein you suffer fairly long delays.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Latency - Propagation of Data
# ***

# %% [markdown]
# And there can be several types of delays, propagation of data, meaning that you have to get the data from one point usually to many different destinations.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Latency - Transmission Delays
# ***

# %% [markdown]
# Transmission delays whereby there could be different properties of the physical medium, again, in terms of wireless, it's what it has to travel through in many cases that can cause delays.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Latency - Processing Delays
# ***

# %% [markdown]
# And of course processing delays when you simply have too many interconnection devices such as proxy servers and or routers or network hops.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Latency Tools
# ***

# %% [markdown]
# Now you can measure the latency.

# %% [markdown]
# There are a variety of network tools that can be used to determine the time it takes for a packet to travel from the source, to the destination, including Ping and Traceroute.

# %% [markdown]
# And in some cases, you might also want to know the round trip time. So source to destination, and then back again.

# %% [markdown]
# But ideally knowing what kind of latency you are dealing with can help you to fine tune and to troubleshoot so that you can decrease the amount of latency.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Jitter
# ***

# %% [markdown]
# Now jitter also occurs in wireless networks and this is a variation in the delay of received packets between two systems.

# %% [markdown]
# And quite literally they can arrive out of sequence.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So as such, you can still encounter jitter, particularly if there is high congestion, improper queuing and/or configuration errors of the interconnection devices or the wireless access points themselves.

# %% [markdown]
# So when things do start to jitter in a wireless connection, you end up with the same problems.

# %% [markdown]
# Particularly with real-time communication such as IP telephony or voice over IP or video conferencing, things, quite literally, get garbled up. You hear a certain word before another word is supposed to actually be heard, so you hear them in the wrong sequence or it just doesn't make any sense whatsoever.

# %% [markdown]
# And the video picture might jump around and, quite literally, be rather jittery, if you will. So the less jitter, the better in these real-time communications.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Attenuation
# ***

# %% [markdown]
# Attenuation is still an issue with wireless signals as well.

# %% [markdown]
# This is the reduction of signal strength, and this occurs during transmission, and is still represented in decibels.

# %% [markdown]
# And it can occur with any type of signal, whether it's digital or analog, and in many cases, it's just referred to as loss.

# %% [markdown]
# But when dealing with wireless, there are several different obstacles that can, of course, accumulate up, depending on how much any given section of the signal has to travel through.

# %% [markdown]
# So you see a table here that lists out what kind of material, and how much attenuation is associated with that material. So that you can get a bit of an idea as to how much loss you will encounter as the signal passes through these obstacles. [A table labelled Wireless Attenuation displays showing a list of materials and signal attenuations measured in decibels for each. It says: Glass window, 2db; Wooden door, 3db; Cubicle 3 – 5db; Plasterboard wall, 3db; Drywall, 4db; Cinderblock, 5db; Marble 5db; Glass wall with metal frame, 6db; Brick wall, 8db; Concrete wall, 10 – 15db.]

# %% [markdown]
# So glass windows, wooden doors, cubicles, plaster board walls, drywall, cinderblock, marble, glass wall with metal frame, brick walls.

# %% [markdown]
# And concrete walls, of course are all things that we expect to encounter in most office buildings or even in your home, of course.

# %% [markdown]
# So you can see the amount of loss or attenuation increases as you go down that list.

# %% [markdown]
# So concrete walls of course represent the most attenuation so you would want to avoid those as much as possible.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Deployment Considerations
# ***

# %% [markdown]
# So when deploying a wireless environment, there are several considerations.

# %% [markdown]
# Review the facility diagram if it's available, because often times it's hard to know what is actually sitting between the access point and the reception point.

# %% [markdown]
# Visually inspect the diagram and/or do a walk through. Again, if you can, locate where the users actually are.

# %% [markdown]
# Identify what is hopefully the best access point locations, and of course document your findings. And that may have to change from time to time.

# %% [markdown]
# Office buildings will undergo renovations and floor plans will change, so you kind of have to go along with that, of course.

# %% [markdown]
# But ideally, perfect world, you want nothing in between the access point and the receiving units, but that's just not possible in most cases. So the fewer obstacles, the better.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssues3IncorrectAntennaTypesandPlacement"></a>
# ***
# ###### 3. Incorrect Antenna Types and Placement
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot incorrect antenna types and antenna placements``

# %% [markdown]
# In this presentation we'll talk about some issues that you may encounter with your antennas in a wireless environment.

# %% [markdown]
# Beginning with the type, you might encounter simply the wrong type depending on what it is you're trying to achieve.

# %% [markdown]
# There are different Wi-Fi antennas and each is designed for a specific purpose.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Directional versus Omnidirectional Antenna
# ***

# %% [markdown]
# Most notably, the directional antenna, which is designed to focus on certain areas of coverage, versus the omnidirectional antenna, which is designed for 360-degree coverage.

# %% [markdown]
# So in some cases, you might know that you only want wireless in this particular area of a building for example. And in that case, you would want the directional antenna.

# %% [markdown]
# But if it's something like a hotel, or an airport, or a public library or something along those lines where it's fairly large and fairly open. And you want everyone to be able to have access regardless of where they are, then of course you need the omnidirectional.

# %% [markdown]
# So again, just ensure that you have the correct type for whatever it is you are trying to achieve.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Incorrect Antenna Aiming
# ***

# %% [markdown]
# Now there can also be issues with aiming, and this is a little more common on some of the legacy access points that used what are known as diversity antennas. And this is essentially just trading off one antenna to the other. When it detects a packet, it will try to negotiate the best signal over one antenna versus the other.

# %% [markdown]
# And the position, and/or the aiming of those antennas can actually make a difference.

# %% [markdown]
# Now, I do suggest you do a little bit of research on the position. I have seen conflicting statements that say you should position them like this, or like that. And it tends to change from time to time, and again, there are several other factors that can, of course, interfere with any given signal. So you always have to take that into consideration as well.

# %% [markdown]
# But if they are improperly aligned, it could be detrimental to signal performance.

# %% [markdown]
# So perhaps a little bit of trial and error might be the best solution.

# %% [markdown]
# But I've seen many documents say that both antennas should be pointing straight up. I've seen as many that say one should be pointing straight up and one should be pointing horizontally. Almost perpendicular to it, so the two antenna make an L if you will, and a few other configurations. So again, perhaps a little trial and error might be the best option there.

# %% [markdown]
# But another possible issue is what's known as hidden node. And this occurs when two clients in opposite directions connect to the same access point but effectively cannot detect each other.

# %% [markdown]
# So in other words, if you just imagine a circle then the access point is in the middle. Then one client is completely on the left side at the maximum range and the other client is completely on the right side at the maximum range. Each of them within range of the access point but not really within range of each other. Now, that doesn't really matter per say in terms of being able to exchange a packet, because they both still go through the access point. But recall that this is still an Ethernet network, and Ethernet specifies that two systems cannot send a packet over the same medium at the same time. Now, the medium in this case is just the air but you are still sending packets over the air at the same time in many cases and they quite simply will collide. You will still get collisions in wireless networks, so the fact that client A doesn't really see client B in terms of their distance. In essence means that they will both try to communicate at the same time with the access point, and in many cases this will actually cause a collision. Because of course the transmissions, event though they might be weak, they will still meet up with each other and that's a collision. So that, of course, will degrade the performance of the network.

# %% [markdown]
# So ideally, you want all of the systems to be able to see the access point and to see each other, because then they can do what Ethernet does.

# %% [markdown]
# They can listen, they can implement carrier sense multiple access with collision detection and collision avoidance. And they can see that system B is transmitting right now, so I will hold off and system B does the same thing. It sees that system A is transmitting so it will hold off so that these collisions of course, do not occur.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Trial and Error - Spectrum Analyzer
# ***

# %% [markdown]
# So again with respect to configuring your particular implementation, a little bit of trial and error certainly won't hurt. But if you do have something like a spectrum analyzer and you can get a very good picture of what the wireless signal is going to look like, then you can hopefully avoid some of these problems before they begin.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssues4InterferenceOvercapacityandChannelOverlap"></a>
# ***
# ###### 4. Interference, Overcapacity, and Channel Overlap
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot interference, overcapacity, and channel overlap``

# %% [markdown]
# In this presentation we'll talk about some Wi-Fi issues including interference, channel assignment and capacity problems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Interference
# ***

# %% [markdown]
# So beginning with interference, of course, these are just radio transmission.

# %% [markdown]
# So other Wi-Fi networks in the same range as yours can cause problems. So something like your neighbor's Wi-Fi if you are at home, or another company Wi-Fi in the same building, can certainly interfere with your transmissions. Again, they are just radio signals, and they can quite literally interfere with each other because they are transmitting on the same frequency. So again, it's like trying to tune your radio to two stations at once, it just doesn't work.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Dual Band Routers
# ***

# %% [markdown]
# So, you might consider using dual band routers, they can operate simultaneously over the 2.4 GHz or the 5 GHz band.

# %% [markdown]
# So if for example, those that are surrounding you are operating at 2.4, if you were to simply switch to 5, that really should alleviate the issue. But you can't always do that because of some compatibility issues. But if you can, then certainly consider that as an option.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Electronics
# ***

# %% [markdown]
# And you might also be experiencing interference from standard household devices, microwaves, cordless phones.

# %% [markdown]
# Not cell phones but typically land lines that are cordless, and even baby monitors all operate over that 2.4 GHz band.

# %% [markdown]
# So again, switching to the 5 GHz band might alleviate some issues there.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bluetooth Devices
# ***

# %% [markdown]
# Bluetooth devices have been known in the past to interfere, but these days, I would say this would be a very minimal consideration.

# %% [markdown]
# But computer keyboards, mice, hands-free devices, they are still transmitting.

# %% [markdown]
# But again, modern implementations of Bluetooth have effectively corrected some of the interference issues. But if you have some older devices still around, that could be an issue.

# %% [markdown]
# But again, probably fairly minor.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Security Settings
# ***

# %% [markdown]
# In some cases, upgrading the security settings might have an effect.

# %% [markdown]
# The encryption, for example, if you do increase it, that might impact the performance. I would say that's probably more common on inexpensive routers, but increased encryption does require more processing. So that can just have an effect on the overall performance of the device itself.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Old Firmware
# ***

# %% [markdown]
# And similarly old firmware can also degrade the performance.

# %% [markdown]
# So, you would always want to try to keep that firmware up to date if possible, because the vendors typically do of course tend to release new features.

# %% [markdown]
# They tend to try to improve the security and the overall performance, so it’s a good idea to always check the date on the firmware.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Channel Assignments
# ***

# %% [markdown]
# Channel assignments of course can still cause problems if any two devices that are needing to communicate have an incorrect channel assignment.

# %% [markdown]
# Which is a little more common with the legacy band usage, but this of course can affect the data rates as well.

# %% [markdown]
# But many deployments do use the 2.4 GHz radio spectrum, and in which case there really are only three channels that don't overlap. Recall that any one channel in fact covers a little bit of a range of the overall 2.4 GHz band. So channels 1, 6, and 11 are far enough away from each other that they do not overlap.

# %% [markdown]
# So that's, in essence, what you want to use. Because if you have devices that are using channels 2, and 3, and 4, then they are in fact overlapping the frequency, so they can interfere.

# %% [markdown]
# So ideally, 1, 6, and 11, or any set of values that just don't overlap.

# %% [markdown]
# So channel 3 for example is far enough away from channel 8, that if you were using those two they would not overlap.

# %% [markdown]
# But by default, 1, 6 and 11 are set, and they don't overlap with each other. So, you know, that's typically what you would want to try to use.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Capacity
# ***

# %% [markdown]
# In terms of capacity, when you are all using the same access point, then of course, you are ultimately sharing the capacity for all of the connections, both up and downstream from the access point.

# %% [markdown]
# So, for example, with an 802.11g access point, all connecting devices are sharing the overall capability of that device which is 54 Mbps per second.

# %% [markdown]
# And this can be further reduced by some of the processing overhead, and actually I'll give you an example of that in a moment.

# %% [markdown]
# But if you use a newer implementation such as 802.11n or ac, then they actually use wider channels and features such as MIMO, multiple input, multiple output to increase the overall capacity.

# %% [markdown]
# So again, some newer devices will help there, but you can't always just go straight to the newest devices because of backward compatibility issues.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### AP Device Capacity
# ***

# %% [markdown]
# So the device capacity is something that you do need to be aware of, most access points or routers will only support a limited number of devices in total.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Lower-end Devices
# ***

# %% [markdown]
# And if it's a lower end device then you might experience other limitations such as not enough RAM and not enough processing.

# %% [markdown]
# And that comes back to what I mentioned a moment ago, the fact that in essence there's a little bit of overhead associated with the device itself.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Other Features - MAC Filtering - NAT - Firewall
# ***

# %% [markdown]
# And there are also other features that, of course, use the resources of the access point or the router.

# %% [markdown]
# If you have implemented MAC filtering, network address translation and firewall rules, that's more processing.

# %% [markdown]
# So the more processing you have to do, of course the slower the device will become overall.

# %% [markdown]
# Now again, these aren't tremendously demanding features, but the more systems that are communicating over that access point that all require this type of processing. You are simply taking away from the ability of the access point or the router to do what it normally does.

# %% [markdown]
# So it is something to be mindful of and if you can increase the resources of the device itself, then that will certainly help.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Newer Devices
# ***

# %% [markdown]
# Ultimately, the newer devices with the newer capabilities and more available resources will certainly help to alleviate a lot of these issues. So try your best to keep on top of the newer devices. But again, you can't always just go straight to the newest devices because you have older devices that need the backward compatibility. So you always have to try to find that balance, but try to stay as current as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssues5DistanceLimitationsandFrequencyMismatches"></a>
# ***
# ###### 5. Distance Limitations and Frequency Mismatches
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``given a scenario, troubleshoot distance limitation issues and frequenc mismatches``

# %% [markdown]
# Some other issues that can arise in terms of wireless connectivity can include problems with the frequency and of course, the distance.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Frequency - 2.4 GHz - Less Congested 5 GHz
# ***

# %% [markdown]
# So with respect to the frequency, recall that Wi-Fi operates most often at 2.4 GHz, but some of the newer devices certainly support the 5 GHz band.

# %% [markdown]
# Which, at this point, is less congested, but perhaps not as compatible depending on the devices you are dealing with.

# %% [markdown]
# But, although 2.4 might be a little more common, it is actually a little more susceptible to interference as well.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Frequency - Channel Configuration
# ***

# %% [markdown]
# And also bear in mind the channel configuration.

# %% [markdown]
# Now, a channel is just collection of subdivisions of the band. And any one channel in fact does overlap those subdivisions.

# %% [markdown]
# So in terms of setting the channels, you want to ensure that you are using values that are far enough apart that they actually don't overlap.

# %% [markdown]
# For example, in the 2.4 GHz band, channels 1, 6 and 11 are typically used because they are far enough apart that the overlapping subdivisions don't actually overlap each other.

# %% [markdown]
# So again, 6 is far enough away from 1, for example, that there is no overlap of the frequencies.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Distance
# ***

# %% [markdown]
# Now distance, of course, is one of the most common problems because wireless signals can only travel a certain range.

# %% [markdown]
# So the farther you get from the access point, the less likely it is that you'll be able to connect.

# %% [markdown]
# So the performance can be impacted by walls, corners, various materials and other interference, including signals from other devices.

# %% [markdown]
# So again, ideally you want to be as close as possible to your access point and you want as little interference and as few obstructions as possible. So in essence, try to determine the optimal placement for your routers and access points.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Distance Issues
# ***

# %% [markdown]
# So look at something that is as central as possible. Look for where you have the highest traffic.

# %% [markdown]
# Look for areas with less interference, such as other Wi-Fi networks and various other types of electronics.

# %% [markdown]
# And also pay attention to the proper orientation of the antennas so that you can maximize the signal strength.

# %% [markdown]
# And in essence, ensure that you have the highest quality for those who are within range.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssues6WrongSSIDandPassphrases"></a>
# ***
# ###### 6. Wrong SSID and Passphrases
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot issues caused by wrong SSIDs and passphrases``

# %% [markdown]
# In this presentation, we'll take a look at some wireless connectivity issues that can arise with the service set identifier and/or the passphrase.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Service Set Identifier (SSID)
# ***

# %% [markdown]
# Now the SSID is quite simply a network-naming scheme.

# %% [markdown]
# Something that you can call the wireless network.

# %% [markdown]
# So this is a configurable parameter and it needs to be shared by the client and the access point.

# %% [markdown]
# And more importantly, it needs to be consistent on both.

# %% [markdown]
# So a misconfigured SSID, in essence, will prevent the client from being able to connect. Or they might even connect to the wrong network entirely if, for example, they just are typing in the name and they just made a simple typo. But yet there was another wireless within range that matched that name, they might actually connect to it instead of the intended one.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Passphrase
# ***

# %% [markdown]
# Now with respect to the passphrase, this is like any other password, you have to supply the correct one to be able to connect.

# %% [markdown]
# Now it does depend on the security that you have implemented with respect to what the passphrase will look like.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wired Equivalent Privacy (WEP) Protocol
# ***

# %% [markdown]
# So if, for example, WEP is being used, the wired equivalent privacy protocol. Bear in mind this is not considered to be a secure Wi-Fi protocol by today's standards but it is backward compatible.

# %% [markdown]
# So it's not gone, but the passphrase will vary depending on the strength of the encryption.

# %% [markdown]
# At the lower 40 to 64-bit setting, you'll see a 10 hexadecimal character or 5 ASCII character passphrase.

# %% [markdown]
# And if it's the higher setting of 104 up to 128, then you see 26 hexadecimal characters or 13 ASCII characters.

# %% [markdown]
# So that in and of itself actually decreases the security a little bit.

# %% [markdown]
# Because an attacker knows exactly how many characters to deal with, with respect to the passphrase.

# %% [markdown]
# So again, WEP is not considered to be secure.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### WPA/WPA2 Personal
# ***

# %% [markdown]
# But if you see WPA or WPA2, there is the personal edition as well as the enterprise that we'll see in a moment, but this uses much stronger encryption than WEP.

# %% [markdown]
# It uses a combination of the temporal key integrity protocol and the advanced encryption services to provide much stronger encryption.

# %% [markdown]
# And it supports a preshared key of between 8 and 63 characters, and it can be any value in between.

# %% [markdown]
# And so again, attackers do not know how many characters they're dealing with, whereas they do with WEP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### WPA/WPA2 Enterprise
# ***

# %% [markdown]
# And in the enterprise edition, this is often implemented in business environments and provides even more security.

# %% [markdown]
# Although it can be a little more complicated to set up.

# %% [markdown]
# But users are assigned login credentials by administration.

# %% [markdown]
# And those credentials must be presented at logon, and they can be revoked at any time by administration. And in essence, those connectivity credentials are provided to you by administration, and an attacker just, of course, has no idea what the credentials are supposed to look like.

# %% [markdown]
# So it's even more difficult, but the idea behind Enterprise is to allow an administrator to centrally configure all of the connectivity properties and then effectively distribute those or push them out to the clients. So that everyone has their own specific settings with respect to those credentials.

# %% [markdown]
# But ultimately, if the passphrase is incorrect, then you clearly will not be able to connect. So if all of a sudden it seems like you can't connect anymore, then it's very likely the passphrase has been changed on the access point, but your system has not been updated. So of course you need to make that change as soon as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssues7SecurityTypeMismatches"></a>
# ***
# ###### 7. Security Type Mismatches
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``given a scenario troubleshoot security type mismatches``

# %% [markdown]
# In this presentation, we'll take a look at some security type mismatch problems that you might encounter.

# %% [markdown]
# And when it comes to the security types that are available in a Wi-Fi implementation.

# %% [markdown]
# In general you always want to go with the strongest setting, but you may still have to consider backward compatibility.

# %% [markdown]
# In other words, some older devices that are still being used may not support the highest levels of security.

# %% [markdown]
# So this list that you see here is from top to bottom, most secure to least secure.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wi-Fi Protected Access Version 2 (WPA2) + Advanced Encryption Standard (AES)
# ***

# %% [markdown]
# So at the time of this recording, WPA2, Wi-Fi Protected Access version 2, using AES, Advanced Encryption Standard, is the most secure.

# %% [markdown]
# And that is really what you would want to use for all implementations, again, provided that all devices support it.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### WPA2 with Temporal Key Integrity Protocol (TKIP) or AES
# ***

# %% [markdown]
# If you need to bust down to a lower level for backward compatibility, then the next level down is WPA2 with TKIP, or Temporal Key Integrity Protocol, or AES.

# %% [markdown]
# So in essence, it will default to AES if it can use it, but TKIP is there as a fall back method.

# %% [markdown]
# TKIP was the predecessor for AES, but the successor for WEP.

# %% [markdown]
# And it certainly was stronger than WEP, but not as strong as AES. So again, it's just there as a fallback method for a device that does not support AES.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### WPA + TKIP
# ***

# %% [markdown]
# You can go with WPA, the original version, which only supported TKIP.

# %% [markdown]
# It did not support AES. So again, if you need to go yet another level down, then that's the next one.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### WEP
# ***

# %% [markdown]
# And then finally, WEP was in essence the first implementation of Wi-Fi security, and is by today's standards not considered to be secure at all.

# %% [markdown]
# But of course, it is better than an open network where there is no security.

# %% [markdown]
# Now of course, you find open networks all the time at restaurants, or coffee shops, or airports, or things like that. But certainly be mindful that in many cases there is absolutely no security on those networks.

# %% [markdown]
# So in a corporate environment of course, you would not want this option, nor would you want it at home.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Start at the Top - Avoid WEP
# ***

# %% [markdown]
# So again, in essence, start at the top if you can, and as long as all devices support that level, then that is absolutely what you want.

# %% [markdown]
# You'll get your highest levels of security, and even the best levels of performance.

# %% [markdown]
# Even though, there's more processing required for that level of security.

# %% [markdown]
# Of course newer access points, and newer routers are designed to handle it. So they have more processing. They have more memory so that they can give you that security. And in essence, they do actually perform better.

# %% [markdown]
# So again, the general rule of thumb, as high as you can go in terms of the security, while still maintaining compatibility for devices that might not support it. But generally try to avoid WEP and of course, open networks where there is no security.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssues8PowerLevelsandSignaltonoiseRatio"></a>
# ***
# ###### 8. Power Levels and Signal-to-noise Ratio
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot issues related to power levels and signal-to-noise ratio``

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Power Level
# ***

# %% [markdown]
# Another issue that might arise in a wireless implementation is actually the power level of the access point itself.

# %% [markdown]
# Now this, for the most part, is something that you only encounter when attempting to configure wireless access for very large environments, such as warehouses or airports.

# %% [markdown]
# They do have the ability to adjust the power level. And this can negatively affect the coverage and the performance.

# %% [markdown]
# In other words, actually having full power on a device can be problematic. Now, again, it's certainly not guaranteed but it's something that you want to be mindful of.

# %% [markdown]
# Because what happens is that the power level is raised so that clients at a greater distance are able to connect.

# %% [markdown]
# But the problem can in fact be that clients that are actually closer will pick up on that stronger signal and try to associate with that one even though it's farther away.

# %% [markdown]
# So effectively they're trying to reach too far, if you will, rather than connecting to the one that they see right there. They see this signal that comes in and appears to be stronger and they think well, maybe I'll connect to that one instead.

# %% [markdown]
# But then if they move even just a few feet further away, now they're really taxing the limit of that particular signal and they lose the signal.

# %% [markdown]
# So, in essence, they should really remain connected to the one that is closest.

# %% [markdown]
# So this can require some trial and error. And, in essence, determining what the best power level ultimately might be.

# %% [markdown]
# But, surprisingly, you generally don't want to go straight for 100%, if you will. Maybe pull it back to 75 or 60 and just try some configurations and ensure that you are moving around.

# %% [markdown]
# So that you can determine whether or not clients are actually seeing what appears to be a stronger signal. But, of course, is then very vulnerable to just moving a little bit farther away.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Signal-to-Noise Ratio (SNR)
# ***

# %% [markdown]
# So another consideration that the you might want to test for is what's known as the signal to noise ratio, or SNR.

# %% [markdown]
# This is a measure of the quality of the signal.

# %% [markdown]
# And a low SNR can indicate that there is an issue with background noise. In other words, you're getting more noise than signal. So some of the sources of noise can include microwave ovens, wireless devices, fluorescent lights even. But basically anything that can interfere with a radio signal.

# %% [markdown]
# So ideally you want as little of that as possible. You want, in a perfect world, 100% signal and 0% noise. But, you know, that's probably not ever going to happen.

# %% [markdown]
# So the higher the ratio, the better. And ultimately that means you are getting more signal than noise. And clearly that is what you want for your best quality connections.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssuespractice"></a>
# ***
# ### Practice: Wireless Connectivity Issues
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``troubleshoot wireless connectivity issues``

# %% [markdown]
# i. Describe the difference between reflection and refraction.
#
#
# ii. Then to describe the consequences of an incorrect antenna type.
#
#
# iii. Then to recognize security type mismatches.
#
#
# iv. And finally, to recognize issues related to power levels for an access point.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssuesexercise"></a>
# ***
# ###### 1. Exercise: Troubleshoot Wireless Connectivity
# ***

# %% [markdown]
# i. Describe the difference between reflection and refraction.

# %% [markdown]
# - And reflection is, of course, signals bouncing directly off varying types of surfaces. And of course, certain surfaces are much more reflective than others. Glass walls, of course, will reflect more than drywall will.

# %% [markdown]
# - Refraction refers to the signals being redirected or bent by varying materials as it passes through them. And again, different types of materials have different refractive indexes. So that can affect the speed.

# %% [markdown]
# ii. Then we asked to describe the consequences of an incorrect antenna type.

# %% [markdown]
# So this entirely depends on what it is you're trying to implement for your coverage. And there are two main types of antennas, a directional for very focused coverage, or an omnidirectional for 360-degree coverage. So again, it really depends on where you are trying to get your signal. If it's only one specific area, then you should use a directional antenna. But of course, if it's a very large area and people are moving around all over the place, then you need the omnidirectional.

# %% [markdown]
# iii. Then we asked to recognize security type mismatches.

# %% [markdown]
# And in short, the security settings between an access point and a client must match. And in every case, ideally, what you want to use is the highest setting possible, while maintaining compatibility with older devices. And in some cases, you can't just go for the highest setting because of those older devices. But if you can, upgrade everything so that they do support those highest levels. But ultimately, they have to match.

# %% [markdown]
# iv. And finally, we asked you to recognize issues related to power levels.

# %% [markdown]
# And in some cases, there are access points that allow you to adjust the power level. But increasing it can actually cause a client to associate with an access point that is actually farther away, because it sees that very strong signal. But there's another access point that really is much closer to them. So it reassociates with the one farther away. But then if you get up and move, let say, ten feet away, you might be completely stretching the ability of that connection point. And you suddenly lose your signal.

# %% [markdown]
# So again, you don't always want to go with a 100% across the board. This can require a little bit of trial and error and is usually only something that you see for trying to figure out the coverage for a very large area such as an airport or a warehouse. But it's not always recommended to just set everything at 100% power. Sometimes that can backfire.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessConnectivityIssuesTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
